# %% [markdown]
# <h1 style='text-align: center'>Accidents Severity Data Description</h1>

# %% [markdown]
# # Accidents Data at Seattle City
# <p>You are given a car crashes dataset in Seattle, Washingon. Most car crash events either results in loss of life or property, sometimes it results in the vehicle being towed. This dataset contains detailed data of accident severity
# provided by the State Police Department of Seattle. The collected Data was recorded on a weekly basis from 2004 until today.</p>
#
# <b>The Dataset Contains:</b><br>
#    - 39 input attributes: they contain detailed information about the recorded accidents.<br>
#    - 1 output attribute: the car accident severity evaluation, which includes all the types of collisions displayed at the    intersection or mid-block of a segment.

# %%
import pandas as pd
df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
# Out:
# c:\users\user\appdata\local\programs\python\python38-32\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.drop(['COLDETKEY','INTKEY', 'SEVERITYCODE.1', 'SEVERITYDESC', 'ADDRTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC','SDOTCOLNUM', 'ST_COLCODE'], axis =1, inplace = True)
df
# Out:
#         SEVERITYCODE           X          Y  OBJECTID  INCKEY REPORTNO  \
# 0                  2 -122.323148  47.703140         1    1307  3502005
# 1                  1 -122.347294  47.647172         2   52200  2607959
# 2                  1 -122.334540  47.607871         3   26700  1482393
# 3                  1 -122.334803  47.604803         4    1144  3503937
# 4                  2 -122.306426  47.545739         5   17700  1807429
# ...              ...         ...        ...       ...     ...      ...
# 194668             2 -122.290826  47.565408    219543  309534  E871089
# 194669             1 -122.344526  47.690924    219544  309085  E876731
# 194670             2 -122.306689  47.683047    219545  311280  3809984
# 194671             2 -122.355317  47.678734    219546  309514  3810083
# 194672             1 -122.289360  47.611017    219547  308220  E868008
#
#          STATUS                                         LOCATION  \
# 0       Matched                       5TH AVE NE AND NE 103RD ST
# 1       Matched       AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# 2       Matched      4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
# 3       Matched         2ND AVE BETWEEN MARION ST AND MADISON ST
# 4       Matched                  SWIFT AVE S AND SWIFT AV OFF RP
# ...         ...                                              ...
# 194668  Matched  34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST
# 194669  Matched     AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST
# 194670  Matched                       20TH AVE NE AND NE 75TH ST
# 194671  Matched                    GREENWOOD AVE N AND N 68TH ST
# 194672  Matched     34TH AVE BETWEEN E MARION ST AND E SPRING ST
#
#        EXCEPTRSNCODE EXCEPTRSNDESC  ... UNDERINFL   WEATHER  ROADCOND  \
# 0                              NaN  ...         N  Overcast       Wet
# 1                NaN           NaN  ...         0   Raining       Wet
# 2                NaN           NaN  ...         0  Overcast       Dry
# 3                              NaN  ...         N     Clear       Dry
# 4                NaN           NaN  ...         0   Raining       Wet
# ...              ...           ...  ...       ...       ...       ...
# 194668                         NaN  ...         N     Clear       Dry
# 194669                         NaN  ...         N   Raining       Wet
# 194670                         NaN  ...         N     Clear       Dry
# 194671                         NaN  ...         N     Clear       Dry
# 194672                         NaN  ...         N     Clear       Wet
#
#                       LIGHTCOND  PEDROWNOTGRNT SPEEDING  \
# 0                      Daylight            NaN      NaN
# 1       Dark - Street Lights On            NaN      NaN
# 2                      Daylight            NaN      NaN
# 3                      Daylight            NaN      NaN
# 4                      Daylight            NaN      NaN
# ...                         ...            ...      ...
# 194668                 Daylight            NaN      NaN
# 194669                 Daylight            NaN      NaN
# 194670                 Daylight            NaN      NaN
# 194671                     Dusk            NaN      NaN
# 194672                 Daylight            NaN      NaN
#
#                                                ST_COLDESC SEGLANEKEY  \
# 0                                       Entering at angle          0
# 1       From same direction - both going straight - bo...          0
# 2                                  One parked--one moving          0
# 3                        From same direction - all others          0
# 4                                       Entering at angle          0
# ...                                                   ...        ...
# 194668    From opposite direction - both moving - head-on          0
# 194669  From same direction - both going straight - bo...          0
# 194670  From opposite direction - one left turn - one ...          0
# 194671                       Vehicle Strikes Pedalcyclist       4308
# 194672  From same direction - both going straight - on...          0
#
#        CROSSWALKKEY HITPARKEDCAR
# 0                 0            N
# 1                 0            N
# 2                 0            N
# 3                 0            N
# 4                 0            N
# ...             ...          ...
# 194668            0            N
# 194669            0            N
# 194670            0            N
# 194671            0            N
# 194672            0            N
#
# [194673 rows x 29 columns]

# %% [markdown]
# <b>OBJECTID:</b> ObjectID <br>
# <b>INCKEY:</b> Long, A unique key for the incident<br>
# <b>INTKEY</b> Double, Key that corresponds to the intersection associated with a collision<br>
# <b>LOCATION:</b> Text, 255 Description of the general location of the collision<br>
# <b>SEVERITYCODE</b>: Text, 100 A code that corresponds to the severity of the collision<br>
# <b>COLLISIONTYPE:</b> Text, 300 Collision type<br>
# <b>PERSONCOUNT:</b> Double, The total number of people involved in the collision<br>
# <b>PEDCOUNT:</b> Double, The number of pedestrians involved in the collision. This is entered by the state.<br>
# <b>PEDCYLCOUNT:</b> Double, The number of bicycles involved in the collision.This is entered by the state.<br>
# <b>VEHCOUNT:</b> Double, The number of vehicles involved in the collision.This is entered by the state.<br>
# <b>INJURIES:</b> Double, The number of total injuries in the collision. This is entered by the state.<br>
# <b>SERIOUSINJURIES:</b> Double, The number of serious injuries in the collision.This is entered by the state.<br>
# <b>FATALITIES:</b> Double, The number of fatalities in the collision. This is entered by the state.<br>
# <b>INCDATE:</b> Date, The date of the incident.<br>
# <b>INCDTTM:</b> Text, 30 The date and time of the incident.<br>
# <b>JUNCTIONTYPE:</b> Text, 300 Category of junction at which collision took place<br>
# <b>INATTENTIONIND:</b> Text, 1 Whether or not collision was due to inattention.(Y/N)<br>
# <b>UNDERINFL:</b> Text, 10 Whether or not a driver involved was under the influence of drugs or alcohol.<br>
# <b>WEATHER:</b> Text, 300 A description of the weather conditions during the time of the collision.<br>
# <b>ROADCOND:</b> Text, 300 The condition of the road during the collision.<br>
# <b>LIGHTCOND:</b> Text, 300 The light conditions during the collision.<br>
# <b>PEDROWNOTGRNT:</b> Text, 1 Whether or not the pedestrian right of way was not granted. (Y/N)<br>
# <b>SPEEDING:</b> Text, 1 Whether or not speeding was a factor in the collision. (Y/N)<br>
# <b>ST_COLDESC:</b> Text, 300 A description that corresponds to the state’s coding designation.<br>
# <b>SEGLANEKEY:</b> Long, A key for the lane segment in which the collision occurred.<br>
# <b>CROSSWALKKEY:</b> Long, A key for the crosswalk at which the collision occurred.<br>
# <b>HITPARKEDCAR:</b> Text, 1 Whether or not the collision involved hitting a parked car. (Y/N)<br>

# %%
df.T
# Out:
#                                                 0       \
# SEVERITYCODE                                         2
# X                                             -122.323
# Y                                              47.7031
# OBJECTID                                             1
# INCKEY                                            1307
# REPORTNO                                       3502005
# STATUS                                         Matched
# LOCATION                    5TH AVE NE AND NE 103RD ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Angles
# PERSONCOUNT                                          2
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          0
# VEHCOUNT                                             2
# INCDATE                         2013/03/27 00:00:00+00
# INCDTTM                           3/27/2013 2:54:00 PM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            N
# WEATHER                                       Overcast
# ROADCOND                                           Wet
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                           Entering at angle
# SEGLANEKEY                                           0
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                            1       \
# SEVERITYCODE                                                    1
# X                                                        -122.347
# Y                                                         47.6472
# OBJECTID                                                        2
# INCKEY                                                      52200
# REPORTNO                                                  2607959
# STATUS                                                    Matched
# LOCATION               AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N
# EXCEPTRSNCODE                                                 NaN
# EXCEPTRSNDESC                                                 NaN
# COLLISIONTYPE                                           Sideswipe
# PERSONCOUNT                                                     2
# PEDCOUNT                                                        0
# PEDCYLCOUNT                                                     0
# VEHCOUNT                                                        2
# INCDATE                                    2006/12/20 00:00:00+00
# INCDTTM                                     12/20/2006 6:55:00 PM
# JUNCTIONTYPE              Mid-Block (not related to intersection)
# INATTENTIONIND                                                NaN
# UNDERINFL                                                       0
# WEATHER                                                   Raining
# ROADCOND                                                      Wet
# LIGHTCOND                                 Dark - Street Lights On
# PEDROWNOTGRNT                                                 NaN
# SPEEDING                                                      NaN
# ST_COLDESC      From same direction - both going straight - bo...
# SEGLANEKEY                                                      0
# CROSSWALKKEY                                                    0
# HITPARKEDCAR                                                    N
#
#                                                      2       \
# SEVERITYCODE                                              1
# X                                                  -122.335
# Y                                                   47.6079
# OBJECTID                                                  3
# INCKEY                                                26700
# REPORTNO                                            1482393
# STATUS                                              Matched
# LOCATION        4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST
# EXCEPTRSNCODE                                           NaN
# EXCEPTRSNDESC                                           NaN
# COLLISIONTYPE                                    Parked Car
# PERSONCOUNT                                               4
# PEDCOUNT                                                  0
# PEDCYLCOUNT                                               0
# VEHCOUNT                                                  3
# INCDATE                              2004/11/18 00:00:00+00
# INCDTTM                              11/18/2004 10:20:00 AM
# JUNCTIONTYPE        Mid-Block (not related to intersection)
# INATTENTIONIND                                          NaN
# UNDERINFL                                                 0
# WEATHER                                            Overcast
# ROADCOND                                                Dry
# LIGHTCOND                                          Daylight
# PEDROWNOTGRNT                                           NaN
# SPEEDING                                                NaN
# ST_COLDESC                           One parked--one moving
# SEGLANEKEY                                                0
# CROSSWALKKEY                                              0
# HITPARKEDCAR                                              N
#
#                                                   3       \
# SEVERITYCODE                                           1
# X                                               -122.335
# Y                                                47.6048
# OBJECTID                                               4
# INCKEY                                              1144
# REPORTNO                                         3503937
# STATUS                                           Matched
# LOCATION        2ND AVE BETWEEN MARION ST AND MADISON ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                        NaN
# COLLISIONTYPE                                      Other
# PERSONCOUNT                                            3
# PEDCOUNT                                               0
# PEDCYLCOUNT                                            0
# VEHCOUNT                                               3
# INCDATE                           2013/03/29 00:00:00+00
# INCDTTM                             3/29/2013 9:26:00 AM
# JUNCTIONTYPE     Mid-Block (not related to intersection)
# INATTENTIONIND                                       NaN
# UNDERINFL                                              N
# WEATHER                                            Clear
# ROADCOND                                             Dry
# LIGHTCOND                                       Daylight
# PEDROWNOTGRNT                                        NaN
# SPEEDING                                             NaN
# ST_COLDESC              From same direction - all others
# SEGLANEKEY                                             0
# CROSSWALKKEY                                           0
# HITPARKEDCAR                                           N
#
#                                                 4       \
# SEVERITYCODE                                         2
# X                                             -122.306
# Y                                              47.5457
# OBJECTID                                             5
# INCKEY                                           17700
# REPORTNO                                       1807429
# STATUS                                         Matched
# LOCATION               SWIFT AVE S AND SWIFT AV OFF RP
# EXCEPTRSNCODE                                      NaN
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Angles
# PERSONCOUNT                                          2
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          0
# VEHCOUNT                                             2
# INCDATE                         2004/01/28 00:00:00+00
# INCDTTM                           1/28/2004 8:04:00 AM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            0
# WEATHER                                        Raining
# ROADCOND                                           Wet
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                           Entering at angle
# SEGLANEKEY                                           0
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                 5       \
# SEVERITYCODE                                         1
# X                                             -122.388
# Y                                              47.6906
# OBJECTID                                             6
# INCKEY                                          320840
# REPORTNO                                       E919477
# STATUS                                         Matched
# LOCATION                    24TH AVE NW AND NW 85TH ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Angles
# PERSONCOUNT                                          2
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          0
# VEHCOUNT                                             2
# INCDATE                         2019/04/20 00:00:00+00
# INCDTTM                           4/20/2019 5:42:00 PM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            N
# WEATHER                                          Clear
# ROADCOND                                           Dry
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                           Entering at angle
# SEGLANEKEY                                           0
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                 6       \
# SEVERITYCODE                                         1
# X                                             -122.338
# Y                                              47.6185
# OBJECTID                                             7
# INCKEY                                           83300
# REPORTNO                                       3282542
# STATUS                                         Matched
# LOCATION                    DENNY WAY AND WESTLAKE AVE
# EXCEPTRSNCODE                                      NaN
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Angles
# PERSONCOUNT                                          2
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          0
# VEHCOUNT                                             2
# INCDATE                         2008/12/09 00:00:00+00
# INCDTTM                                      12/9/2008
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            0
# WEATHER                                        Raining
# ROADCOND                                           Wet
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                           Entering at angle
# SEGLANEKEY                                           0
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                 7       \
# SEVERITYCODE                                         2
# X                                             -122.321
# Y                                              47.6141
# OBJECTID                                             9
# INCKEY                                          330897
# REPORTNO                                       EA30304
# STATUS                                         Matched
# LOCATION                        BROADWAY AND E PIKE ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Cycles
# PERSONCOUNT                                          3
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          1
# VEHCOUNT                                             1
# INCDATE                         2020/04/15 00:00:00+00
# INCDTTM                           4/15/2020 5:47:00 PM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            N
# WEATHER                                          Clear
# ROADCOND                                           Dry
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                Vehicle Strikes Pedalcyclist
# SEGLANEKEY                                        6855
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                  8       \
# SEVERITYCODE                                          1
# X                                              -122.336
# Y                                               47.6119
# OBJECTID                                             10
# INCKEY                                            63400
# REPORTNO                                        2071243
# STATUS                                          Matched
# LOCATION            PINE ST BETWEEN 5TH AVE AND 6TH AVE
# EXCEPTRSNCODE                                       NaN
# EXCEPTRSNDESC                                       NaN
# COLLISIONTYPE                                Parked Car
# PERSONCOUNT                                           2
# PEDCOUNT                                              0
# PEDCYLCOUNT                                           0
# VEHCOUNT                                              2
# INCDATE                          2006/06/15 00:00:00+00
# INCDTTM                            6/15/2006 1:00:00 PM
# JUNCTIONTYPE    Mid-Block (not related to intersection)
# INATTENTIONIND                                      NaN
# UNDERINFL                                             0
# WEATHER                                           Clear
# ROADCOND                                            Dry
# LIGHTCOND                                      Daylight
# PEDROWNOTGRNT                                       NaN
# SPEEDING                                            NaN
# ST_COLDESC                       One parked--one moving
# SEGLANEKEY                                            0
# CROSSWALKKEY                                          0
# HITPARKEDCAR                                          N
#
#                                                 9       ...  \
# SEVERITYCODE                                         2  ...
# X                                             -122.385  ...
# Y                                              47.5285  ...
# OBJECTID                                            12  ...
# INCKEY                                           58600  ...
# REPORTNO                                       2072105  ...
# STATUS                                         Matched  ...
# LOCATION                 41ST AVE SW AND SW THISTLE ST  ...
# EXCEPTRSNCODE                                      NaN  ...
# EXCEPTRSNDESC                                      NaN  ...
# COLLISIONTYPE                                   Angles  ...
# PERSONCOUNT                                          2  ...
# PEDCOUNT                                             0  ...
# PEDCYLCOUNT                                          0  ...
# VEHCOUNT                                             2  ...
# INCDATE                         2006/03/20 00:00:00+00  ...
# INCDTTM                           3/20/2006 3:49:00 PM  ...
# JUNCTIONTYPE    At Intersection (intersection related)  ...
# INATTENTIONIND                                     NaN  ...
# UNDERINFL                                            0  ...
# WEATHER                                          Clear  ...
# ROADCOND                                           Dry  ...
# LIGHTCOND                                     Daylight  ...
# PEDROWNOTGRNT                                      NaN  ...
# SPEEDING                                           NaN  ...
# ST_COLDESC                           Entering at angle  ...
# SEGLANEKEY                                           0  ...
# CROSSWALKKEY                                         0  ...
# HITPARKEDCAR                                         N  ...
#
#                                                            194663  \
# SEVERITYCODE                                                    2
# X                                                        -122.299
# Y                                                         47.5797
# OBJECTID                                                   219536
# INCKEY                                                     309335
# REPORTNO                                                  E880807
# STATUS                                                    Matched
# LOCATION        RAINIER AVE S BETWEEN S BAYVIEW ST AND S MCCLE...
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                                 NaN
# COLLISIONTYPE                                              Angles
# PERSONCOUNT                                                     3
# PEDCOUNT                                                        0
# PEDCYLCOUNT                                                     0
# VEHCOUNT                                                        2
# INCDATE                                    2019/01/09 00:00:00+00
# INCDTTM                                      1/9/2019 12:51:00 PM
# JUNCTIONTYPE              Mid-Block (not related to intersection)
# INATTENTIONIND                                                  Y
# UNDERINFL                                                       N
# WEATHER                                                   Raining
# ROADCOND                                                      Wet
# LIGHTCOND                                                Daylight
# PEDROWNOTGRNT                                                 NaN
# SPEEDING                                                      NaN
# ST_COLDESC                                      Entering at angle
# SEGLANEKEY                                                      0
# CROSSWALKKEY                                                    0
# HITPARKEDCAR                                                    N
#
#                                                 194664  \
# SEVERITYCODE                                         1
# X                                             -122.326
# Y                                              47.6432
# OBJECTID                                        219537
# INCKEY                                          309222
# REPORTNO                                       E879537
# STATUS                                         Matched
# LOCATION               EASTLAKE AVE E AND E ROANOKE ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Angles
# PERSONCOUNT                                          8
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          0
# VEHCOUNT                                             3
# INCDATE                         2018/12/30 00:00:00+00
# INCDTTM                          12/30/2018 3:25:00 PM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            N
# WEATHER                                          Clear
# ROADCOND                                           Dry
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                           Entering at angle
# SEGLANEKEY                                           0
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                 194665  \
# SEVERITYCODE                                         1
# X                                             -122.304
# Y                                              47.6695
# OBJECTID                                        219538
# INCKEY                                          308480
# REPORTNO                                       3642620
# STATUS                                         Matched
# LOCATION               NE PARK RD AND NE RAVENNA WB BV
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Angles
# PERSONCOUNT                                          2
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          0
# VEHCOUNT                                             2
# INCDATE                         2018/12/05 00:00:00+00
# INCDTTM                           12/5/2018 1:00:00 PM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            N
# WEATHER                                          Clear
# ROADCOND                                           Dry
# LIGHTCOND                                     Daylight
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                           Entering at angle
# SEGLANEKEY                                           0
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                       194666  \
# SEVERITYCODE                                               2
# X                                                   -122.345
# Y                                                    47.6945
# OBJECTID                                              219539
# INCKEY                                                309170
# REPORTNO                                             E879712
# STATUS                                               Matched
# LOCATION        AURORA AVE N BETWEEN N 90TH ST AND N 91ST ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                            NaN
# COLLISIONTYPE                                         Angles
# PERSONCOUNT                                                2
# PEDCOUNT                                                   0
# PEDCYLCOUNT                                                0
# VEHCOUNT                                                   2
# INCDATE                               2019/01/04 00:00:00+00
# INCDTTM                                  1/4/2019 1:46:00 PM
# JUNCTIONTYPE         Mid-Block (not related to intersection)
# INATTENTIONIND                                           NaN
# UNDERINFL                                                  N
# WEATHER                                                Clear
# ROADCOND                                                 Wet
# LIGHTCOND                                           Daylight
# PEDROWNOTGRNT                                            NaN
# SPEEDING                                                 NaN
# ST_COLDESC                                 Entering at angle
# SEGLANEKEY                                                 0
# CROSSWALKKEY                                               0
# HITPARKEDCAR                                               N
#
#                                                            194667  \
# SEVERITYCODE                                                    1
# X                                                        -122.362
# Y                                                         47.5567
# OBJECTID                                                   219541
# INCKEY                                                     307804
# REPORTNO                                                  3745813
# STATUS                                                    Matched
# LOCATION        PUGET BLVD SW BETWEEN SW HUDSON ST AND DEAD END 1
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                                 NaN
# COLLISIONTYPE                                               Other
# PERSONCOUNT                                                     1
# PEDCOUNT                                                        0
# PEDCYLCOUNT                                                     0
# VEHCOUNT                                                        1
# INCDATE                                    2018/11/28 00:00:00+00
# INCDTTM                                     11/28/2018 9:34:00 PM
# JUNCTIONTYPE              Mid-Block (not related to intersection)
# INATTENTIONIND                                                NaN
# UNDERINFL                                                       Y
# WEATHER                                                   Raining
# ROADCOND                                                      Wet
# LIGHTCOND                                 Dark - Street Lights On
# PEDROWNOTGRNT                                                 NaN
# SPEEDING                                                      NaN
# ST_COLDESC                                           Fixed object
# SEGLANEKEY                                                      0
# CROSSWALKKEY                                                    0
# HITPARKEDCAR                                                    N
#
#                                                          194668  \
# SEVERITYCODE                                                  2
# X                                                      -122.291
# Y                                                       47.5654
# OBJECTID                                                 219543
# INCKEY                                                   309534
# REPORTNO                                                E871089
# STATUS                                                  Matched
# LOCATION        34TH AVE S BETWEEN S DAKOTA ST AND S GENESEE ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                               NaN
# COLLISIONTYPE                                           Head On
# PERSONCOUNT                                                   3
# PEDCOUNT                                                      0
# PEDCYLCOUNT                                                   0
# VEHCOUNT                                                      2
# INCDATE                                  2018/11/12 00:00:00+00
# INCDTTM                                   11/12/2018 8:12:00 AM
# JUNCTIONTYPE            Mid-Block (not related to intersection)
# INATTENTIONIND                                              NaN
# UNDERINFL                                                     N
# WEATHER                                                   Clear
# ROADCOND                                                    Dry
# LIGHTCOND                                              Daylight
# PEDROWNOTGRNT                                               NaN
# SPEEDING                                                    NaN
# ST_COLDESC      From opposite direction - both moving - head-on
# SEGLANEKEY                                                    0
# CROSSWALKKEY                                                  0
# HITPARKEDCAR                                                  N
#
#                                                            194669  \
# SEVERITYCODE                                                    1
# X                                                        -122.345
# Y                                                         47.6909
# OBJECTID                                                   219544
# INCKEY                                                     309085
# REPORTNO                                                  E876731
# STATUS                                                    Matched
# LOCATION             AURORA AVE N BETWEEN N 85TH ST AND N 86TH ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                                 NaN
# COLLISIONTYPE                                          Rear Ended
# PERSONCOUNT                                                     2
# PEDCOUNT                                                        0
# PEDCYLCOUNT                                                     0
# VEHCOUNT                                                        2
# INCDATE                                    2018/12/18 00:00:00+00
# INCDTTM                                     12/18/2018 9:14:00 AM
# JUNCTIONTYPE              Mid-Block (not related to intersection)
# INATTENTIONIND                                                  Y
# UNDERINFL                                                       N
# WEATHER                                                   Raining
# ROADCOND                                                      Wet
# LIGHTCOND                                                Daylight
# PEDROWNOTGRNT                                                 NaN
# SPEEDING                                                      NaN
# ST_COLDESC      From same direction - both going straight - bo...
# SEGLANEKEY                                                      0
# CROSSWALKKEY                                                    0
# HITPARKEDCAR                                                    N
#
#                                                            194670  \
# SEVERITYCODE                                                    2
# X                                                        -122.307
# Y                                                          47.683
# OBJECTID                                                   219545
# INCKEY                                                     311280
# REPORTNO                                                  3809984
# STATUS                                                    Matched
# LOCATION                               20TH AVE NE AND NE 75TH ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                                 NaN
# COLLISIONTYPE                                           Left Turn
# PERSONCOUNT                                                     3
# PEDCOUNT                                                        0
# PEDCYLCOUNT                                                     0
# VEHCOUNT                                                        2
# INCDATE                                    2019/01/19 00:00:00+00
# INCDTTM                                      1/19/2019 9:25:00 AM
# JUNCTIONTYPE               At Intersection (intersection related)
# INATTENTIONIND                                                NaN
# UNDERINFL                                                       N
# WEATHER                                                     Clear
# ROADCOND                                                      Dry
# LIGHTCOND                                                Daylight
# PEDROWNOTGRNT                                                 NaN
# SPEEDING                                                      NaN
# ST_COLDESC      From opposite direction - one left turn - one ...
# SEGLANEKEY                                                      0
# CROSSWALKKEY                                                    0
# HITPARKEDCAR                                                    N
#
#                                                 194671  \
# SEVERITYCODE                                         2
# X                                             -122.355
# Y                                              47.6787
# OBJECTID                                        219546
# INCKEY                                          309514
# REPORTNO                                       3810083
# STATUS                                         Matched
# LOCATION                 GREENWOOD AVE N AND N 68TH ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                      NaN
# COLLISIONTYPE                                   Cycles
# PERSONCOUNT                                          2
# PEDCOUNT                                             0
# PEDCYLCOUNT                                          1
# VEHCOUNT                                             1
# INCDATE                         2019/01/15 00:00:00+00
# INCDTTM                           1/15/2019 4:48:00 PM
# JUNCTIONTYPE    At Intersection (intersection related)
# INATTENTIONIND                                     NaN
# UNDERINFL                                            N
# WEATHER                                          Clear
# ROADCOND                                           Dry
# LIGHTCOND                                         Dusk
# PEDROWNOTGRNT                                      NaN
# SPEEDING                                           NaN
# ST_COLDESC                Vehicle Strikes Pedalcyclist
# SEGLANEKEY                                        4308
# CROSSWALKKEY                                         0
# HITPARKEDCAR                                         N
#
#                                                            194672
# SEVERITYCODE                                                    1
# X                                                        -122.289
# Y                                                          47.611
# OBJECTID                                                   219547
# INCKEY                                                     308220
# REPORTNO                                                  E868008
# STATUS                                                    Matched
# LOCATION             34TH AVE BETWEEN E MARION ST AND E SPRING ST
# EXCEPTRSNCODE
# EXCEPTRSNDESC                                                 NaN
# COLLISIONTYPE                                          Rear Ended
# PERSONCOUNT                                                     2
# PEDCOUNT                                                        0
# PEDCYLCOUNT                                                     0
# VEHCOUNT                                                        2
# INCDATE                                    2018/11/30 00:00:00+00
# INCDTTM                                     11/30/2018 3:45:00 PM
# JUNCTIONTYPE              Mid-Block (not related to intersection)
# INATTENTIONIND                                                NaN
# UNDERINFL                                                       N
# WEATHER                                                     Clear
# ROADCOND                                                      Wet
# LIGHTCOND                                                Daylight
# PEDROWNOTGRNT                                                 NaN
# SPEEDING                                                      NaN
# ST_COLDESC      From same direction - both going straight - on...
# SEGLANEKEY                                                      0
# CROSSWALKKEY                                                    0
# HITPARKEDCAR                                                    N
#
# [29 rows x 194673 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 29 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   OBJECTID        194673 non-null  int64
#  4   INCKEY          194673 non-null  int64
#  5   REPORTNO        194673 non-null  object
#  6   STATUS          194673 non-null  object
#  7   LOCATION        191996 non-null  object
#  8   EXCEPTRSNCODE   84811 non-null   object
#  9   EXCEPTRSNDESC   5638 non-null    object
#  10  COLLISIONTYPE   189769 non-null  object
#  11  PERSONCOUNT     194673 non-null  int64
#  12  PEDCOUNT        194673 non-null  int64
#  13  PEDCYLCOUNT     194673 non-null  int64
#  14  VEHCOUNT        194673 non-null  int64
#  15  INCDATE         194673 non-null  object
#  16  INCDTTM         194673 non-null  object
#  17  JUNCTIONTYPE    188344 non-null  object
#  18  INATTENTIONIND  29805 non-null   object
#  19  UNDERINFL       189789 non-null  object
#  20  WEATHER         189592 non-null  object
#  21  ROADCOND        189661 non-null  object
#  22  LIGHTCOND       189503 non-null  object
#  23  PEDROWNOTGRNT   4667 non-null    object
#  24  SPEEDING        9333 non-null    object
#  25  ST_COLDESC      189769 non-null  object
#  26  SEGLANEKEY      194673 non-null  int64
#  27  CROSSWALKKEY    194673 non-null  int64
#  28  HITPARKEDCAR    194673 non-null  object
# dtypes: float64(2), int64(9), object(18)
# memory usage: 29.7+ MB

# %%
df.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY    PERSONCOUNT       PEDCOUNT    PEDCYLCOUNT  \
# count  194673.000000  194673.000000  194673.000000  194673.000000
# mean   141091.456350       2.444427       0.037139       0.028391
# std     86634.402737       1.345929       0.198150       0.167413
# min      1001.000000       0.000000       0.000000       0.000000
# 25%     70383.000000       2.000000       0.000000       0.000000
# 50%    123363.000000       2.000000       0.000000       0.000000
# 75%    203319.000000       3.000000       0.000000       0.000000
# max    331454.000000      81.000000       6.000000       2.000000
#
#             VEHCOUNT     SEGLANEKEY  CROSSWALKKEY
# count  194673.000000  194673.000000  1.946730e+05
# mean        1.920780     269.401114  9.782452e+03
# std         0.631047    3315.776055  7.226926e+04
# min         0.000000       0.000000  0.000000e+00
# 25%         2.000000       0.000000  0.000000e+00
# 50%         2.000000       0.000000  0.000000e+00
# 75%         2.000000       0.000000  0.000000e+00
# max        12.000000  525241.000000  5.239700e+06
